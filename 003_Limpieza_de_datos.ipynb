# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df2 = df.sample(n=20)

# %%
df2 = df.sample(n=20, random_state= 42)

# %% [markdown]
# El random state o semilla en programación es un valor fijo que garantiza que los resultados de un proceso aleatorio sean reproducibles. Al fijar la semilla, el algoritmo genera siempre la misma secuencia de números aleatorios, permitiendo que los experimentos o modelos produzcan los mismos resultados en cada ejecución.

# %%
df2.shape
# Out:
# (20, 15)

# %%
df2.to_excel('ejemplo.xlsx', index=True)

# %%
df2.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 709         1       3    male   NaN      1      1  15.2458        C   Third
# 439         0       2    male  31.0      0      0  10.5000        S  Second
# 840         0       3    male  20.0      0      0   7.9250        S   Third
# 720         1       2  female   6.0      0      1  33.0000        S  Second
# 39          1       3  female  14.0      1      0  11.2417        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 709    man        True  NaN    Cherbourg   yes  False
# 439    man        True  NaN  Southampton    no   True
# 840    man        True  NaN  Southampton    no   True
# 720  child       False  NaN  Southampton   yes  False
# 39   child       False  NaN    Cherbourg   yes  False

# %%
df2.shape
# Out:
# (20, 15)

# %%
sns.scatterplot(x=df["fare"], y=df["age"], hue = df['alive'], markers = True )
# Out:
# <Axes: xlabel='fare', ylabel='age'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lmplot(data=df, x='fare', y='age', hue='sex')

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# # Limpieza de Datos
# ## Eliminación y Sustitución de Valores Nulos
# En primer lugar, verificaremos si existen valores nulos en el dataset:

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# Podemos observar que existen valores nulos en las columnas 'age', 'deck' y 'embark_town'.
#
# Podemos eliminar la columna 'deck' ya que contiene muchos valores nulos y no es relevante para nuestro análisis. Además, eliminaremos la columna 'embark_town' porque ya tenemos la información en la columna 'embarked'.

# %% [markdown]
# Nota:
#
#
# *   NaN = Not a Number, se genera cuando intentamos escribir un valor no numerico en un campo numerico (ej: str en campo numerico)
# *   Null = Valor Nulo o inexistente, se genera si no tenemos el valor correspondiente para ese campo en esa linea determinada o si el valor está corrupto.
# *   Na = Null

# %%
df2 = df.sort_values(by='age', ascending=True, na_position='first')
df2.head()
# Out:
#     survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5          0       3    male  NaN      0      0   8.4583        Q   Third
# 17         1       2    male  NaN      0      0  13.0000        S  Second
# 19         1       3  female  NaN      0      0   7.2250        C   Third
# 26         0       3    male  NaN      0      0   7.2250        C   Third
# 28         1       3  female  NaN      0      0   7.8792        Q   Third
#
#       who  adult_male deck  embark_town alive  alone
# 5     man        True  NaN   Queenstown    no   True
# 17    man        True  NaN  Southampton   yes   True
# 19  woman       False  NaN    Cherbourg   yes   True
# 26    man        True  NaN    Cherbourg    no   True
# 28  woman       False  NaN   Queenstown   yes   True

# %% [markdown]
# ORDENA DE ARRIBA HACIA ABAJO(FIRST) O DE ABAJO HACIA ARRIBA(LAST) LOS VALORES NULOS

# %%
df2.tail()
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
#
#      adult_male deck  embark_town alive  alone
# 116        True  NaN   Queenstown    no   True
# 493        True  NaN    Cherbourg    no   True
# 96         True    A    Cherbourg    no   True
# 851        True  NaN  Southampton    no   True
# 630        True    A  Southampton   yes   True

# %% [markdown]
# muestra las últimas 5 filas de df2 por defecto. Es útil para inspeccionar los datos finales de tu DataFrame y verificar su contenido.
#
# Si quieres ver más o menos filas, puedes especificar el número de filas como argumento, por ejemplo, df2.tail(10) mostrará las últimas 10 filas.

# %%
df2 = df2.drop(['deck', 'embark_town'], axis=1)

# %%
df2 = df2.drop(862)

# %%
df2 = df2.sort_values(by='age', ascending=True, na_position='first')
df2.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 831         1       2    male  0.83      1      1  18.7500        S  Second
#
#        who  adult_male alive  alone
# 803  child       False   yes  False
# 755  child       False   yes  False
# 469  child       False   yes  False
# 644  child       False   yes  False
# 831  child       False   yes  False

# %%
df2.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      2
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# En cuanto a la columna 'age', podemos sustituir los valores nulos por la mediana de la columna:

# %%
df2['age'] = df2['age'].fillna(df2['age'].median())

# %%
df2 = df

# %%
df2['age'] = df2['age'].fillna(90)

# %% [markdown]
# Reemplaza los nulos con el valor 90

# %%
df2.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male  90.0      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
df2 = df2.drop(['deck', 'embark_town'], axis=1)

# %%
df2.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age           0
# sibsp         0
# parch         0
# fare          0
# embarked      2
# class         0
# who           0
# adult_male    0
# alive         0
# alone         0
# dtype: int64

# %% [markdown]
# ## Eliminación de Duplicados
# Luego, verificaremos si existen registros duplicados en el dataset:

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df['Duplicated'] = df.duplicated()

# %% [markdown]
# añade una nueva columna llamada Duplicated al DataFrame df. Esta nueva columna indica si cada fila es una duplicada o no.

# %%
Relevant_columns = ['class','age']

# %%
df['Duplicated_class'] = df.duplicated(Relevant_columns)

# %% [markdown]
# Verifica si hay filas duplicadas en el DataFrame df basándose solo en las columnas especificadas en Relevant_columns (es decir, 'class' y 'age'). Devuelve una serie booleana donde cada valor es True si la fila es un duplicado en función de las columnas seleccionadas y False en caso contrario.

# %%
df[df['Duplicated_class']==False].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Duplicated  \
# 0    man        True  NaN  Southampton    no  False       False
# 1  woman       False    C    Cherbourg   yes  False       False
# 2  woman       False  NaN  Southampton   yes   True       False
# 3  woman       False    C  Southampton   yes  False       False
# 4    man        True  NaN  Southampton    no   True       False
#
#    Duplicated_class
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# muestra las primeras 5 filas de df que no tienen duplicados en las columnas especificadas.

# %%
df[df['Duplicated']==True].head(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female  90.0      0      0   7.7500        Q   Third
# 76          0       3    male  90.0      0      0   7.8958        S   Third
# 77          0       3    male  90.0      0      0   8.0500        S   Third
# 87          0       3    male  90.0      0      0   8.0500        S   Third
# 95          0       3    male  90.0      0      0   8.0500        S   Third
# 101         0       3    male  90.0      0      0   7.8958        S   Third
# 121         0       3    male  90.0      0      0   8.0500        S   Third
# 133         1       2  female  29.0      1      0  26.0000        S  Second
# 173         0       3    male  21.0      0      0   7.9250        S   Third
# 196         0       3    male  90.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  Duplicated  \
# ...

# %% [markdown]
# filtra el DataFrame df para mostrar las primeras 10 filas que son duplicadas.

# %%
df.duplicated(subset=['embark_town']).sum()
# Out:
# 887

# %% [markdown]
# Luego podríamos proceder a eliminar estos valores en caso de determinar que es necesario

# %%
df3 = df.drop_duplicates()
df3.duplicated().sum()
# Out:
# 0

# %%
df3[df3['Duplicated']==False].head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Duplicated  \
# 0    man        True  NaN  Southampton    no  False       False
# 1  woman       False    C    Cherbourg   yes  False       False
# 2  woman       False  NaN  Southampton   yes   True       False
# 3  woman       False    C  Southampton   yes  False       False
# 4    man        True  NaN  Southampton    no   True       False
#
#    Duplicated_class
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %% [markdown]
# ## Filtrado de Datos
# Podemos filtrar los datos para obtener un subconjunto del dataset que cumpla con ciertas condiciones. Por ejemplo, podemos obtener un subconjunto con los pasajeros que sobrevivieron al desastre:

# %%
df_survived = df[df['survived']==1]

# %% [markdown]
# el == 1 se utiliza para filtrar el DataFrame df y seleccionar solo aquellas filas donde la columna 'survived' tiene un valor de 1.

# %%
df_survived.shape
# Out:
# (342, 17)

# %%
df_female = df[df['sex']!='male']

# %% [markdown]
# un nuevo DataFrame que contiene solo las filas del DataFrame original df en las que el género no es masculino.

# %%
df_female.shape
# Out:
# (314, 17)

# %% [markdown]
# ## Unión de Datasets
# Podemos unir datasets diferentes para agregar información adicional. Por ejemplo:

# %%
# Crear dataset 1
data_1 = {'id': [1, 2, 3, 4],
          'nombre': ['Juan', 'Pedro', 'Ana', 'Marta'],
          'otro': ['6', '4', '3', '2']}
dataset_1 = pd.DataFrame(data_1)
dataset_1.head()
# Out:
#    id nombre otro
# 0   1   Juan    6
# 1   2  Pedro    4
# 2   3    Ana    3
# 3   4  Marta    2

# %%
# Crear dataset 2
data_2 = {'id': [1, 2, 5, 2],
          'edad': [25, 35, 40, 30],
          'nombre': ['Juan', 'Pedro', 'Ana', 'Marta']}
dataset_2 = pd.DataFrame(data_2)
dataset_2.head()
# Out:
#    id  edad nombre
# 0   1    25   Juan
# 1   2    35  Pedro
# 2   5    40    Ana
# 3   2    30  Marta

# %%
# Unir datasets
dataset = pd.merge(dataset_1, dataset_2, on=['id','nombre'], how='left')
dataset.head()
# Out:
#    id nombre otro  edad
# 0   1   Juan    6  25.0
# 1   2  Pedro    4  35.0
# 2   3    Ana    3   NaN
# 3   4  Marta    2   NaN

# %% [markdown]
# La función merge en pandas se utiliza para combinar dos DataFrames basándose en columnas comunes o índices. Es una herramienta muy poderosa para realizar uniones similares a las de las bases de datos SQL.

# %%
dataset_concat = pd.concat([dataset_1,dataset_2], axis =0)

# %%
dataset_concat.head(10)
# Out:
#    id nombre otro  edad
# 0   1   Juan    6   NaN
# 1   2  Pedro    4   NaN
# 2   3    Ana    3   NaN
# 3   4  Marta    2   NaN
# 0   1   Juan  NaN  25.0
# 1   2  Pedro  NaN  35.0
# 2   5    Ana  NaN  40.0
# 3   2  Marta  NaN  30.0

# %% [markdown]
# ## Eliminación de Columnas Innecesarias
# Podemos eliminar las columnas que no son relevantes para nuestro análisis. Por ejemplo, podemos eliminar las columnas 'class' y 'who':

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Duplicated  \
# 0    man        True  NaN  Southampton    no  False       False
# 1  woman       False    C    Cherbourg   yes  False       False
# 2  woman       False  NaN  Southampton   yes   True       False
# 3  woman       False    C  Southampton   yes  False       False
# 4    man        True  NaN  Southampton    no   True       False
#
#    Duplicated_class
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df4 = df.drop(['class', 'who'], axis=1)
df4.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  adult_male  \
# 0         0       3    male  22.0      1      0   7.2500        S        True
# 1         1       1  female  38.0      1      0  71.2833        C       False
# 2         1       3  female  26.0      0      0   7.9250        S       False
# 3         1       1  female  35.0      1      0  53.1000        S       False
# 4         0       3    male  35.0      0      0   8.0500        S        True
#
#   deck  embark_town alive  alone  Duplicated  Duplicated_class
# 0  NaN  Southampton    no  False       False             False
# 1    C    Cherbourg   yes  False       False             False
# 2  NaN  Southampton   yes   True       False             False
# 3    C  Southampton   yes  False       False             False
# 4  NaN  Southampton    no   True       False             False

# %% [markdown]
# ## Conversión de Tipos de Datos
# Podemos convertir los tipos de datos de las columnas según sea necesario. Por ejemplo, podemos convertir la columna 'sex' a valores numéricos:

# %%
df5 = df
df5.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  Duplicated  \
# 0    man        True  NaN  Southampton    no  False       False
# 1  woman       False    C    Cherbourg   yes  False       False
# 2  woman       False  NaN  Southampton   yes   True       False
# 3  woman       False    C  Southampton   yes  False       False
# 4    man        True  NaN  Southampton    no   True       False
#
#    Duplicated_class
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
df5['sex'] = df5['sex'].pma({'male': 0, 'female': 1})

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   survived          891 non-null    int64
#  1   pclass            891 non-null    int64
#  2   sex               891 non-null    int64
#  3   age               891 non-null    float64
#  4   sibsp             891 non-null    int64
#  5   parch             891 non-null    int64
#  6   fare              891 non-null    float64
#  7   embarked          889 non-null    object
#  8   class             891 non-null    category
#  9   who               891 non-null    object
#  10  adult_male        891 non-null    bool
#  11  deck              203 non-null    category
#  12  embark_town       889 non-null    object
#  13  alive             891 non-null    object
#  14  alone             891 non-null    bool
#  15  Duplicated        891 non-null    bool
# ...

# %%
df5['sex'] = df5['sex'].fillna(0)
df5.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class
# 0        True  NaN  Southampton    no  False       False             False
# 1       False    C    Cherbourg   yes  False       False             False
# 2       False  NaN  Southampton   yes   True       False             False
# 3       False    C  Southampton   yes  False       False             False
# 4        True  NaN  Southampton    no   True       False             False

# %% [markdown]
# .fillna(0): Reemplaza los valores nulos (NaN) en la columna 'sex' con 0.

# %%
df51 = df

# %%
df51.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    0  22.0      1      0   7.2500        S  Third    man
# 1         1       1    1  38.0      1      0  71.2833        C  First  woman
# 2         1       3    1  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    1  35.0      1      0  53.1000        S  First  woman
# 4         0       3    0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class
# 0        True  NaN  Southampton    no  False       False             False
# 1       False    C    Cherbourg   yes  False       False             False
# 2       False  NaN  Southampton   yes   True       False             False
# 3       False    C  Southampton   yes  False       False             False
# 4        True  NaN  Southampton    no   True       False             False

# %%
df51['sex'] = df51['sex'].astype('float64')

# %%
df51.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   survived          891 non-null    int64
#  1   pclass            891 non-null    int64
#  2   sex               891 non-null    float64
#  3   age               891 non-null    float64
#  4   sibsp             891 non-null    int64
#  5   parch             891 non-null    int64
#  6   fare              891 non-null    float64
#  7   embarked          889 non-null    object
#  8   class             891 non-null    category
#  9   who               891 non-null    object
#  10  adult_male        891 non-null    bool
#  11  deck              203 non-null    category
#  12  embark_town       889 non-null    object
#  13  alive             891 non-null    object
#  14  alone             891 non-null    bool
#  15  Duplicated        891 non-null    bool
# ...

# %%
df51.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  0.0  22.0      1      0   7.2500        S  Third    man
# 1         1       1  1.0  38.0      1      0  71.2833        C  First  woman
# 2         1       3  1.0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1  1.0  35.0      1      0  53.1000        S  First  woman
# 4         0       3  0.0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class
# 0        True  NaN  Southampton    no  False       False             False
# 1       False    C    Cherbourg   yes  False       False             False
# 2       False  NaN  Southampton   yes   True       False             False
# 3       False    C  Southampton   yes  False       False             False
# 4        True  NaN  Southampton    no   True       False             False

# %% [markdown]
# ### Normalización de Datos
#
# Podemos normalizar los datos para que tengan una misma escala.
# Esto es especialmente útil en algoritmos de machine learning y análisis de datos, donde las diferencias en la escala de las características pueden afectar el rendimiento del modelo.

# %%
from sklearn.preprocessing import MinMaxScaler

df6 = df

# %% [markdown]
# ### MinMaxScaler:
#
# Es un metodo de normalizacion que utiliza los valores minimos y maximos de la dimension para normalizar la escala:
#
# X_scaled = (X - X_min) / (X_max - X_min)
#
# donde X es el valor original de la característica, X_max es el valor maximo de la característica y X_min es el valor minimo

# %%
df6.head(10)
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked   class    who  \
# 0         0       3  0.0  22.0      1      0   7.2500        S   Third    man
# 1         1       1  1.0  38.0      1      0  71.2833        C   First  woman
# 2         1       3  1.0  26.0      0      0   7.9250        S   Third  woman
# 3         1       1  1.0  35.0      1      0  53.1000        S   First  woman
# 4         0       3  0.0  35.0      0      0   8.0500        S   Third    man
# 5         0       3  0.0  90.0      0      0   8.4583        Q   Third    man
# 6         0       1  0.0  54.0      0      0  51.8625        S   First    man
# 7         0       3  0.0   2.0      3      1  21.0750        S   Third  child
# 8         1       3  1.0  27.0      0      2  11.1333        S   Third  woman
# 9         1       2  1.0  14.0      1      0  30.0708        C  Second  child
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class
# ...

# %%
scaler = MinMaxScaler()
df6['age_normalized'] = scaler.fit_transform(df6[['age']])

# %%
df6.head(10)
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked   class    who  \
# 0         0       3  0.0  22.0      1      0   7.2500        S   Third    man
# 1         1       1  1.0  38.0      1      0  71.2833        C   First  woman
# 2         1       3  1.0  26.0      0      0   7.9250        S   Third  woman
# 3         1       1  1.0  35.0      1      0  53.1000        S   First  woman
# 4         0       3  0.0  35.0      0      0   8.0500        S   Third    man
# 5         0       3  0.0  90.0      0      0   8.4583        Q   Third    man
# 6         0       1  0.0  54.0      0      0  51.8625        S   First    man
# 7         0       3  0.0   2.0      3      1  21.0750        S   Third  child
# 8         1       3  1.0  27.0      0      2  11.1333        S   Third  woman
# 9         1       2  1.0  14.0      1      0  30.0708        C  Second  child
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class  \
# ...

# %% [markdown]
# Normalización Min-Max: Útil cuando necesitas un rango específico y tus datos no tienen muchos valores atípicos.

# %% [markdown]
# ### Estandarización (StandardScaler):
# La estandarización es una técnica de normalización que escala los datos para que tengan una media de cero y una desviación estándar de uno. La fórmula para la estandarización es:
#
# X_std = (X - mean(X)) / std(X)
#
# donde X es el valor original de la característica, mean(X) es la media de la característica, y std(X) es la desviación estándar de la característica.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df6['age_standardized'] = scaler.fit_transform(df6[['age']])

# %%
df6.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  0.0  22.0      1      0   7.2500        S  Third    man
# 1         1       1  1.0  38.0      1      0  71.2833        C  First  woman
# 2         1       3  1.0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1  1.0  35.0      1      0  53.1000        S  First  woman
# 4         0       3  0.0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class  \
# 0        True  NaN  Southampton    no  False       False             False
# 1       False    C    Cherbourg   yes  False       False             False
# 2       False  NaN  Southampton   yes   True       False             False
# 3       False    C  Southampton   yes  False       False             False
# 4        True  NaN  Southampton    no   True       False             False
#
#    age_normalized  age_standardized
# ...

# %% [markdown]
# Cuandose usa? entre otros motivos,cuando los datos tienen diferentes escalas:
#
# Si tus características tienen diferentes unidades o escalas (por ejemplo, una columna mide la altura en centímetros y otra mide el peso en kilogramos), StandardScaler ayuda a ponerlas en una escala comparable.
# Ejemplo: En un dataset donde una columna mide el salario en dólares y otra mide la edad en años.

# %% [markdown]
# ## Eliminación de Outliers
# Podemos eliminar los outliers para reducir el impacto que tienen en nuestros análisis. Por ejemplo, podemos eliminar los registros que tengan un valor de tarifa mayor a 500:

# %%
df.shape
# Out:
# (891, 19)

# %%
df7 = df[df['fare']<=500]
df7.shape
# Out:
# (888, 19)

# %% [markdown]
# ## Creación de Nuevas Variables
# Podemos crear nuevas variables a partir de las variables existentes. Por ejemplo, podemos crear una variable 'family_size' que represente el tamaño de la familia:

# %%
df['family_size'] = df['sibsp'] + df['parch'] + 1
df.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  0.0  22.0      1      0   7.2500        S  Third    man
# 1         1       1  1.0  38.0      1      0  71.2833        C  First  woman
# 2         1       3  1.0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1  1.0  35.0      1      0  53.1000        S  First  woman
# 4         0       3  0.0  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone  Duplicated  Duplicated_class  \
# 0        True  NaN  Southampton    no  False       False             False
# 1       False    C    Cherbourg   yes  False       False             False
# 2       False  NaN  Southampton   yes   True       False             False
# 3       False    C  Southampton   yes  False       False             False
# 4        True  NaN  Southampton    no   True       False             False
#
#    age_normalized  age_standardized  family_size
# ...

# %% [markdown]
# Esta columna representa el tamaño total de la familia de cada pasajero a bordo del Titanic.

# %%
###lista=[2, 100, 101, 102, 101, 102, 103, 102, 100, 99, 100]
df=pd.DataFrame(lista)
print(df)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['standardized'] = scaler.fit_transform(df[[0]])
print(df.head())###
# Out:
#       0
# 0     2
# 1   100
# 2   101
# 3   102
# 4   101
# 5   102
# 6   103
# 7   102
# 8   100
# 9    99
# 10  100
#      0  standardized
# 0    2     -3.159796
# 1  100      0.280871
# 2  101      0.315980
# 3  102      0.351088
# 4  101      0.315980
